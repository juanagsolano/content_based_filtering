# %% [markdown]
# # Adding keywords, collections and regions features

# %% [markdown]
# ## Extracting keywords features

# %% [markdown]
# ### Import all movies dataframe

# %%
import pandas as pd
df_movies = pd.read_json("json_dict\movie_ids_03_16_2022.json", lines=True)
df_movies.set_index('id', inplace=True)
df_movies.sort_index(inplace=True)
df_movies.head()
# Out:
#     adult                    original_title  popularity  video
# id
# 2   False                             Ariel       9.408  False
# 3   False              Varjoja paratiisissa      10.931  False
# 5   False                        Four Rooms      13.555  False
# 6   False                    Judgment Night      10.250  False
# 8   False  Life in Loops (A Megacities RMX)       3.416  False

# %% [markdown]
# ### Import all keywords dictionary

# %%
import json

keywords_list = []
with open("json_dict\keyword_ids_03_24_2022.json", "r", encoding="utf-8") as f:
    for line in f:
        keywords_list.append(json.loads(line))
keywords_dict = {}
for keyword in keywords_list:
    keywords_dict[keyword["id"]] = keyword["name"]
del keywords_list
keywords_dict
# Out:
# {378: 'prison',
#  240: 'underdog',
#  1787: 'helsinki, finland',
#  730: 'factory worker',
#  1361: 'salesclerk',
#  4529: 'diplomat',
#  1008: 'guerrilla warfare',
#  612: 'hotel',
#  613: "new year's eve",
#  616: 'witch',
#  622: 'bet',
#  2700: 'sperm',
#  922: 'hotel room',
#  2231: 'drug dealer',
#  520: 'chicago, illinois',
#  3737: 'dying and death',
#  544: 'sailboat',
#  10013: 'death star',
#  11195: 'empire',
#  4270: 'galaxy',
#  7376: 'princess',
#  10084: 'rescue',
#  11196: 'rebellion',
#  4932: 'farm',
#  1589: 'sniper',
#  9678: 'mind control',
#  2964: 'future',
#  434: 'destruction of a civilization',
#  803: 'android',
#  8122: 'canyon',
#  4271: 'hermit',
#  6917: 'epic',
#  1612: 'spacecraft',
#  5419: 'bootlegger',
#  2546: 'mask',
#  1357: 'fish',
#  658: 'sea',
#  5656: 'sydney, australia',
#  5657: 'australia',
#  2957: 'vietnam war',
#  422: 'vietnam veteran',
#  791: 'mentally disabled',
#  5136: 'uniform',
#  1525: 'puberty',
#  2918: 'estate agent',
#  2919: 'rose garden',
#  2337: 'pedophilia',
#  5600: 'daughter',
#  2921: 'school friend',
#  2922: 'suburbian idyll',
#  596: 'adultery',
#  1862: 'coming out',
#  894: 'depression',
#  2087: 'lolita',
#  2201: 'first time',
#  566: 'sexual identity',
#  2389: 'virgin',
#  1326: 'infidelity',
#  6270: 'high school',
#  3587: 'media tycoon',
#  3658: 'career',
#  1196: 'florida',
#  242: 'new york city',
#  3660: 'art collector',
#  918: 'newspaper',
#  2110: 'capitalist',
#  736: 'journalist',
#  3661: 'sleigh',
#  2613: 'luxury',
#  2199: 'opera',
#  3515: 'banker',
#  3664: 'research',
#  30: 'individual',
#  2356: 'immigrant',
#  1382: 'factory',
#  1741: 'blindness and impaired vision',
#  246: 'dancing',
#  1691: 'dance',
#  4580: 'van',
#  2122: 'death penalty',
#  6054: 'friendship',
#  2480: 'eye operation',
#  2481: 'eyesight',
#  1415: 'small town',
#  1328: 'secret',
#  2487: 'naivety',
#  2488: 'self-abandonment',
#  2489: 'hereditary disease',
#  2490: 'loss of eyesight',
#  2624: 'czech',
#  1209: 'wales',
#  516: 'child abuse',
#  1450: 'shepherd',
#  704: 'adolescence',
#  439: 'paradise',
#  236: 'suicide',
#  3020: 'sheep',
#  391: 'flying car',
#  444: 'taxi',
#  4812: 'plan',
#  1160: 'egypt',
#  4776: 'race against time',
#  5564: 'match',
#  3799: 'ship',
#  10364: 'mission',
#  1761: 'metropolis',
#  3640: 'work',
#  2346: 'worker',
#  4034: 'class society',
#  5965: 'marxism',
#  312: 'man vs machine',
#  1001: 'underground world',
#  5966: 'tower of babel',
#  3223: 'machine town',
#  455: 'farewell',
#  456: 'mother',
#  1329: 'canada',
#  4225: 'night shift',
#  7879: 'secret love',
#  5349: 'surfing',
#  1524: 'surfer',
#  1671: 'surfboard',
#  1318: 'blacksmith',
#  1319: 'east india company',
#  1321: 'gold',
#  1454: 'treasure',
#  1456: 'medallion',
#  911: 'exotic island',
#  1459: 'marriage proposal',
#  1860: 'mutiny',
#  1605: 'new love',
#  5744: 'governor',
#  3242: 'cannon',
#  4062: 'skeleton',
#  2041: 'island',
#  6293: 'telescope',
#  779: 'martial arts',
#  233: 'japan',
#  780: 'kung fu',
#  387: 'california',
#  782: 'assassin',
#  1462: 'samurai',
#  2952: 'gulf war',
#  5174: 'saudi arabia',
#  3588: 'navy',
#  1701: 'hero',
#  5175: 'petrol',
#  536: 'israel',
#  5907: 'israeli–palestinian conflict',
#  220: 'berlin, germany',
#  376: 'neo-nazism',
#  2072: 'chauffeur',
#  6441: 'dead sea',
#  3037: 'mossad',
#  212: 'london, england',
#  6029: 'concert',
#  445: 'pornography',
#  578: "rock 'n' roll",
#  6935: 'erection',
#  7410: 'fellatio',
#  2956: 'vietnam',
#  2959: 'vietcong',
#  591: 'cia',
#  720: 'helicopter',
#  657: 'fire',
#  2960: 'cambodia',
#  1826: 'space marine',
#  5178: 'magnetic field',
#  5179: 'garbageman ',
#  1865: 'biological weapon',
#  1866: 'bad smell',
#  5198: 'cold',
#  5138: 'gas',
#  6092: 'army',
#  2142: 'anonymity',
#  75: 'gunslinger',
#  549: 'prostitute',
#  796: 'police brutality',
#  797: 'showdown',
#  798: 'sheriff',
#  6145: 'right and justice',
#  801: 'bounty hunter',
#  802: 'regret',
#  1016: 'wyoming, usa',
#  1582: 'saloon',
#  3700: 'garbage',
#  1889: 'lake',
#  6305: 'pollution',
#  6898: 'quarantine',
#  6832: 'environmental protection agency',
#  725: 'lovesickness',
#  966: 'beach',
#  931: 'jealousy',
#  563: 'deja vu',
#  1453: 'amnesia',
#  1565: 'loss of sense of reality',
#  1566: 'dream',
#  1604: 'operation',
#  534: 'mexico',
#  960: 'homeless person',
#  1009: 'baby',
#  642: 'robbery',
#  1547: 'mexico city, mexico',
#  910: 'bondage',
#  1299: 'monster',
#  1316: 'captain',
#  663: 'fortune teller',
#  1317: 'card game',
#  1461: 'compass',
#  1447: 'indiana, usa',
#  570: 'rape',
#  1448: 'distrust',
#  1157: 'husband wife relationship',
#  276: 'philadelphia, pennsylvania',
#  851: 'dual identity',
#  848: 'double life',
#  305: 'moon',
#  306: 'jupiter',
#  310: 'artificial intelligence',
#  311: 'human evolution',
#  314: 'life and death',
#  6104: 'computer',
#  316: 'chess',
#  222: 'schizophrenia',
#  278: 'stockholm syndrome',
#  732: 'coma',
#  733: 'dancer',
#  734: 'bullfight',
#  735: 'torera',
#  514: 'spain',
#  739: 'sexual abuse',
#  897: 'rap music',
#  898: 'hip-hop',
#  899: 'rhyme battle',
#  900: 'trailer park',
#  542: 'street gang',
#  6325: 'ethnic stereotype',
#  441: 'assassination',
#  840: 'usa president',
#  521: 'washington dc, usa',
#  6086: 'government',
#  417: 'corruption',
#  833: 'the white house',
#  537: 'palestine',
#  539: 'middle east',
#  789: 'muslim',
#  393: 'civil war',
#  211: 'bureaucracy',
#  318: 'police state',
#  1025: 'great britain',
#  726: 'drug abuse',
#  532: 'music record',
#  727: 'country music',
#  396: 'transporter',
#  2660: 'strong woman',
#  4327: 'stroke of fate',
#  5212: 'advancement',
#  2684: 'dancing class',
#  5215: 'northern england',
#  1682: "workers' quarter",
#  4112: 'strike',
#  6278: 'scholarship',
#  3927: 'rage and hate',
#  379: 'skinhead',
#  380: 'sibling relationship',
#  11105: 'swastika',
#  586: 'new jersey',
#  447: 'post traumatic stress disorder',
#  793: 'drowning',
#  3800: 'airplane',
#  1563: 'prisoner',
#  839: 'planet mars',
#  83: 'saving the world',
#  843: 'cataclysm',
#  464: 'total destruction',
#  1280: 'laser gun',
#  585: 'casino',
#  1704: 'ambassador',
#  1705: 'congress',
#  1706: 'experiment',
#  2867: 'pest',
#  3243: 'flying saucer',
#  810: 'budapest, hungary',
#  254: 'france',
#  813: 'sunrise',
#  814: 'talking',
#  815: 'soulmates',
#  816: 'walking',
#  822: 'airport',
#  328: 'insulin',
#  331: 'tattoo',
#  828: 'waitress',
#  3973: 'insurance salesman',
#  6017: 'genetics',
#  2157: 'hacker',
#  478: 'china',
#  481: 'imperator',
#  548: 'countryside',
#  90: 'paris, france',
#  817: 'bookshop',
#  818: 'based on novel or book',
#  2038: "love of one's life",
#  332: 'insect',
#  333: 'mushroom',
#  334: 'flying',
#  677: 'nuclear war',
#  1935: 'wind',
#  2763: 'human vs nature',
#  2765: 'fungus spores   ',
#  3391: 'drug smuggling',
#  2151: 'drug crime',
#  416: 'miami, florida',
#  6212: 'smuggling (contraband)',
#  4654: 'undercover agent',
#  269: 'diving',
#  5250: 'red sea',
#  5251: 'primal fear',
#  3030: 'nightmare',
#  4210: 'panic',
#  485: 'nepal',
#  486: 'himalaya',
#  487: 'cairo',
#  488: 'moses',
#  339: 'submarine',
#  2656: 'hat',
#  1294: 'whip',
#  2650: 'leather jacket',
#  1585: 'snake',
#  2853: 'mediterranean',
#  2854: 'ark of the covenant',
#  2856: 'ten commandments',
#  2652: 'nazi',
#  9032: 'excavation',
#  10685: 'escape',
#  6059: 'unsociability',
#  458: 'hippie',
#  459: 'sexual obsession',
#  460: 'free love',
#  463: 'swinger club',
#  508: 'nudist camp',
#  1530: 'temple',
#  2857: 'elephant',
#  2858: 'sacrifice',
#  2859: 'lava',
#  2860: 'heart',
#  2861: 'gallery',
#  2682: 'shanghai, china',
#  5767: 'summer camp',
#  1342: 'dancing master',
#  1343: 'mambo',
#  1346: 'dance performance',
#  113: 'holy grail',
#  110: 'venice, italy',
#  2898: 'armor',
#  2847: 'entrapment',
#  2901: 'crusader',
#  295: 'library',
#  885: 'villa',
#  6149: 'police',
#  5252: 'misery',
#  3032: 'suffering',
#  5253: 'desolateness',
#  5254: 'remoteness',
#  5255: 'hygiene',
#  100: 'slum',
#  3012: 'court case',
#  6148: 'court',
#  933: 'michigan',
#  934: 'judge',
#  1315: 'hays code',
#  1416: 'jazz',
#  1417: 'jurors',
#  128: 'love triangle',
#  2818: 'vernissage',
#  3430: 'pickpocket',
#  258: 'bomb',
#  1423: 'asteroid',
#  1430: 'self sacrifice',
#  641: 'single parent',
#  1432: 'nasa',
#  374: 'arms smuggling',
#  1567: 'intensive care',
#  1568: 'undercover',
#  4286: 'computer program',
#  2812: 'computer virus',
#  282: 'video game',
#  3822: 'teleportation',
#  4563: 'virtual reality',
#  1332: 'cheating',
#  1394: 'gladiator',
#  588: 'rome, italy',
#  502: 'ambush',
#  1395: 'arena',
#  1396: 'colosseum',
#  1399: 'senate',
#  1400: 'swordplay',
#  1402: 'general',
#  1405: 'roman empire',
#  1527: 'gladiator fight',
#  107: 'barcelona, spain',
#  108: 'transvestism',
#  740: 'aids',
#  741: 'transplantation',
#  428: 'nurse',
#  744: 'madrid, spain',
#  571: 'transsexuality',
#  383: 'poker',
#  392: 'england',
#  4523: 'joint',
#  700: 'italian american',
#  1470: 's.w.a.t.',
#  2708: 'hitman',
#  509: 'denmark',
#  3817: 'chance',
#  856: 'paraplegic',
#  978: 'broken engagement',
#  1334: 'wedding vows',
#  1335: 'sense of guilt',
#  794: 'red hair',
#  745: 'nun',
#  1545: 'supermarket',
#  1546: 'ambulance',
#  389: 'clock tower',
#  390: 'skateboarding',
#  830: 'car race',
#  949: 'terrorist',
#  951: 'delorean',
#  952: 'lightning',
#  953: 'guitar',
#  955: 'plutonium',
#  999: 'sports car',
#  1436: 'inventor',
#  414: 'hunter',
#  1291: 'central and south america',
#  1297: 'predator',
#  1302: 'camouflage',
#  3713: 'chase',
#  6075: 'sports',
#  394: 'gypsy',
#  395: 'gambling',
#  397: 'bare knuckle boxing',
#  398: 'slang',
#  1384: 'diamond',
#  1385: 'antwerp',
#  7155: 'receiving of stolen goods',
#  1233: 'composer',
#  4424: 'pain',
#  5257: 'to compose',
#  928: 'hairdresser',
#  2039: 'sexual frustration',
#  4480: 'business man',
#  4694: 'staged death',
#  3739: 'funeral',
#  2863: 'mannequin',
#  1533: 'isolation',
#  4918: 'shadowing',
#  5259: 'english channel',
#  5260: 'geneva, switzerland',
#  701: 'cuba',
#  947: 'prohibition era',
#  924: 'italian',
#  792: 'copenhagen, denmark',
#  6280: 'adult education center',
#  6277: 'language course',
#  188: 'buddhism',
#  1529: 'buddhist monk',
#  1412: 'becoming an adult',
#  1531: 'mountain lake',
#  1532: 'meditation',
#  1534: 'attachment to nature',
#  1536: 'religious education',
#  3743: 'season',
#  2059: 'cycle',
#  2060: 'penalty',
#  2061: 'mortification',
#  2062: 'restart',
#  2063: 'taskmaster',
#  592: 'capitalism',
#  996: 'expensive restaurant',
#  1022: 'workaholic',
#  1023: 'fire escape',
#  418: 'white russian',
#  420: 'bowling',
#  1336: 'ransom',
#  1337: 'carpet',
#  1539: 'fluxus',
#  1541: 'nihilism',
#  1543: 'war veteran',
#  213: 'upper class',
#  1488: 'tennis',
#  1489: 'river thames',
#  567: 'alcohol',
#  715: 'chocolate',
#  985: 'candy',
#  987: 'overweight child',
#  970: 'parent child relationship',
#  990: 'squirrel',
#  1158: 'grandparent grandchild relationship',
#  606: 'orcs',
#  603: 'elves',
#  611: 'hobbit',
#  617: 'shire',
#  604: 'dwarf',
#  619: 'rivendell',
#  5221: 'anduin',
#  1653: 'explosive',
#  4268: 'fort',
#  1786: 'heart attack',
#  6155: 'afterlife',
#  6068: 'influence',
#  4183: 'wife',
#  3409: 'gdansk, poland',
#  2903: 'propaganda',
#  5265: 'spying',
#  5266: 'industrial unrest',
#  5246: "students' movement",
#  2269: 'aquarium',
#  2872: 'window',
#  2109: 'communist',
#  6084: 'political party',
#  1443: 'clerk',
#  5271: 'functionary',
#  5272: 'libya',
#  2605: 'lodz',
#  1994: 'wolf',
#  1721: 'fight',
#  5274: 'iron',
#  5275: 'pan',
#  5276: 'wild boar',
#  5277: 'territory',
#  3762: 'darkness',
#  2640: 'twilight',
#  4931: 'pig',
#  4652: 'bath house',
#  6016: 'biology',
#  2343: 'magic',
#  4152: 'kingdom',
#  6223: 'change',
#  5282: 'the rolling stones',
#  5283: 'hells angels',
#  6085: 'election campaign',
#  2946: 'presidential election',
#  2419: 'staging',
#  6007: 'media',
#  529: 'ku klux klan',
#  530: 'prophecy',
#  531: 'southern usa',
#  787: 'mississippi river',
#  6078: 'politics',
#  4048: 'musician',
#  2570: 'rock star',
#  3490: 'pop star',
#  291: 'circus',
#  5290: 'small person',
#  1907: 'fictitious marriage',
#  1813: 'toxication',
#  2420: 'normality',
#  901: 'groundhog',
#  902: 'weather forecast',
#  903: 'telecaster',
#  904: 'pennsylvania, usa',
#  905: 'alarm clock',
#  1442: 'winter',
#  1521: 'time warp',
#  272: 'transylvania',
#  550: 'call girl',
#  554: 'manager',
#  6271: 'boarding school',
#  776: 'screenplay',
#  3208: 'bunny',
#  2726: 'therapist',
#  5674: 'school presentation',
#  7358: 'school performance',
#  1013: 'homophobia',
#  5809: 'marriage crisis',
#  1019: 'rodeo',
#  2123: 'father murder',
#  2284: 'horseback riding',
#  74: 'germany',
#  259: 'amputation',
#  260: 'disillusion',
#  2504: 'world war i',
#  11139: 'steel helmet',
#  290: 'angel',
#  292: 'berlin wall',
#  4978: 'immortality',
#  6150: 'faith',
#  388: 'scotland',
#  3679: 'society',
#  941: 'tradition',
#  6157: 'prayer',
#  946: 'excommunication',
#  1002: 'authority',
#  1938: 'sword',
#  4809: 'tiger',
#  5742: 'balzac',
#  6267: 'approved school ',
#  449: 'yugoslavia',
#  875: 'dubrovnik',
#  1327: 'war crimes',
#  467: 'megacity',
#  1815: 'atomic bomb',
#  1485: 'stadium',
#  1353: 'underground',
#  2766: 'mutation',
#  1734: 'cop-killer',
#  746: 'vulkan',
#  503: 'federation',
#  582: 'san francisco, california',
#  965: 'age difference',
#  1003: 'photographer',
#  1004: 'commercial',
#  1005: 'karaoke',
#  1007: 'homesickness',
#  1463: 'culture clash',
#  1895: 'jet lag',
#  747: 'genesis',
#  1599: 'midlife crisis',
#  1421: 'birthday',
#  1613: 'terraforming',
#  1615: 'simulator',
#  1617: 'cadet',
#  1618: 'radiation',
#  5218: 'uss reliant',
#  5219: 'ceti alpha v',
#  9537: 'joker',
#  4426: 'sadism',
#  8045: 'russian mafia',
#  4630: 'chaos',
#  892: 'glasgow, scotland',
#  895: 'optimism',
#  1252: 'suicide attempt',
#  1490: 'cleaning lady',
#  2643: 'dead wish',
#  1472: 'starship',
#  697: 'loss of loved one',
#  1824: 'self-destruction',
#  4214: 'beguilement',
#  4720: 'ritual',
#  879: 'brain tumor',
#  270: 'ocean',
#  1322: 'money delivery',
#  823: 'cologne',
#  824: 'drag queen',
#  825: 'support group',
#  827: 'diashow',
#  6026: 'film and cinema',
#  3829: 'beginning',
#  584: 'perfect crime',
#  1435: 'scissors',
#  1437: 'burglar',
#  699: 'love at first sight',
#  587: 'amsterdam, netherlands',
#  977: 'cat',
#  6099: 'jewelry',
#  6197: 'store window',
#  956: 'almanac',
#  248: 'date',
#  5295: 'planetary configuration',
#  6247: 'cleverness',
#  4676: 'whale',
#  5359: 'marine biologist',
#  5360: 'degradation',
#  665: 'uss enterprise-a',
#  3441: 'sentence',
#  1576: 'technology',
#  1601: 'war on drugs',
#  1603: 'extraterrestrial technology',
#  1418: 'skyscraper',
#  1419: 'gun',
#  1375: 'submachine gun',
#  1420: 'gas station',
#  3133: 'vampire',
#  65: 'holiday',
#  1930: 'kidnapping',
#  1562: 'hostage',
#  5362: 'liberation of hostage',
#  2019: 'liberation of prisoners',
#  2768: 'atlantis',
#  2769: 'deep sea',
#  2770: 'war ship',
#  2771: 'octopus',
#  2772: 'diving suit',
#  750: 'rura penthe',
#  559: 'peace conference',
#  4732: 'peace contract',
#  131: 'italy',
#  271: 'competition',
#  560: 'oxygen',
#  629: 'sicily, italy',
#  630: 'dolphin',
#  631: 'apnoe-diving',
#  472: 'bathroom',
#  473: 'chain',
#  1224: 'radio station',
#  3740: 'radio presenter',
#  2045: 'cynic',
#  3600: 'gun rampage',
#  3741: 'talk show',
#  1660: 'suppressed past',
#  1873: 'yuppie',
#  3446: 'forgiveness',
#  3746: 'literature professor',
#  3269: 'secret mission',
#  3754: 'legend',
#  2796: 'self-discovery',
#  3205: 'fairy tale',
#  3305: 'housebreaking',
#  1680: 'boston, massachusetts',
#  407: 'dictator',
#  409: 'africa',
#  836: 'resistance',
#  476: 'self-fulfilling prophecy',
#  5299: 'war correspondent',
#  5300: 'allies',
#  2449: 'black market',
#  6256: 'truth',
#  2534: 'missile',
#  5301: 'brother',
#  5303: 'utah',
#  5304: 'nintendo',
#  2001: 'arms deal',
#  2080: 'stewardess',
#  2081: 'department store',
#  738: 'sexuality',
#  2438: 'social worker',
#  5305: 'gambling debt',
#  1284: 'identity',
#  5306: 'boss',
#  3149: 'gangster',
#  2281: 'mistake in person',
#  1663: 'go-go dancer',
#  6259: 'psychopath',
#  6057: 'peace',
#  5307: 'peace work',
#  1842: 'village life',
#  5308: 'aftermath',
#  4998: 'amends',
#  323: 'raf (royal air force)',
#  324: 'portugal',
#  1526: 'home',
#  186: 'christianity',
#  344: 'inquisition',
#  345: 'monk',
#  347: 'aristotle',
#  351: 'poison',
#  352: 'secret passage',
#  490: 'philosophy',
#  2203: 'unexpected happiness',
#  6025: 'photography',
#  365: 'ghost train',
#  366: 'sex shop',
#  367: 'shyness',
#  1407: 'montmartre',
#  5972: 'garden gnome',
#  5973: 'journey around the world',
#  4129: 'widow',
#  5310: 'approach',
#  385: 'jules verne',
#  386: 'railroad robber',
#  957: 'indian territory',
#  1544: 'locomotive',
#  6089: 'freedom',
#  930: 'in love with enemy',
#  4097: 'independence',
#  2435: 'warsaw ghetto',
#  2444: 'jewish ghetto',
#  2436: 'polish resistance',
#  4679: 'parachuting',
#  11134: 'espionage',
#  11109: 'military officer',
#  522: 'borg',
#  671: 'enterprise-e',
#  679: 'cyborg',
#  680: 'montana',
#  1522: 'repayment',
#  1523: 'obsession',
#  399: 'fountain of youth',
#  402: 'clone',
#  768: 'romulus',
#  1475: 'telepathy',
#  2236: 'protection money',
#  430: 'venezuela',
#  3464: 'tanker',
#  971: 'rwanda',
#  972: 'refugee',
#  973: 'refugee camp',
#  1548: 'hutu',
#  1549: 'tutsi',
#  1550: 'militia',
#  8053: 'rwandan genocide',
#  436: 'south seas',
#  440: 'missionary',
#  493: 'poem',
#  495: 'scapegoat',
#  496: 'poetry',
#  2132: 'literature',
#  1749: 'taxi driver',
#  2300: 'despair',
#  1849: 'homicide',
#  1772: 'german democratic republic',
#  3396: 'probation assistant ',
#  3398: 'release from prison',
#  1591: 'ex-detainee',
#  3399: 'disorientation',
#  470: 'spy',
#  471: 'mount rushmore national memorial',
#  769: 'falsely accused',
#  5920: 'advertising expert',
#  2849: 'key',
#  2380: 'audio tape',
#  3255: 'door',
#  483: 'riddle',
#  525: 'foreigner',
#  7204: 'german-turkish living together',
#  2106: 'cold war',
#  5566: 'maya civilization',
#  5967: 'peru',
#  8790: 'ant-hill',
#  1197: 'nevada',
#  3352: 'tree',
#  4276: 'machinegun',
#  1373: 'killer robot',
#  1366: 'shotgun',
#  526: 'rebel',
#  6156: 'superstition',
#  1571: 'return',
#  1577: 'solidarity',
#  3534: 'big wheel',
#  558: 'city portrait',
#  660: 'monte carlo',
#  964: 'servant',
#  5919: 'necrophilia',
#  6272: "children's home",
#  1992: 'professor',
#  1802: 'revuegirls',
#  6269: 'gymnasium',
#  1227: 'cemetery',
#  5314: 'mill',
#  593: 'globalization',
#  1241: 'persia',
#  1242: 'war on terror',
#  1269: 'energy policy',
#  139: 'anti terror',
#  1356: 'pool billiards',
#  577: 'black people',
#  579: 'american football',
#  5316: 'folk festival',
#  6255: 'insanity',
#  2884: 'asylum',
#  2064: 'overweight',
#  2065: 'province',
#  2067: 'kitsch',
#  2069: 'bathing',
#  2070: 'olympic games',
#  3925: 'boredom',
#  2386: 'empowerment',
#  1422: 'boat',
#  1261: 'river',
#  11325: 'shot to death',
#  11327: 'wedding reception',
#  640: 'transvestite',
#  3342: 'yacht',
#  5320: 'cake',
#  6049: 'praise',
#  625: 'sadistic',
#  627: 'killing',
#  1583: 'mass murder',
#  1584: 'yellow press',
#  716: 'vatican',
#  717: 'pope',
#  718: 'confession',
#  635: 'disc jockey',
#  637: 'pop',
#  639: 'record collection',
#  1338: 'bachelor',
#  690: 'gorilla',
#  886: 'movie business',
#  1339: 'duck',
#  4342: 'geisha',
#  1936: 'blackmail',
#  643: 'horse race',
#  1587: 'way of life',
#  650: 'gymnastics',
#  651: 'candelabrum',
#  974: 'bank',
#  1651: 'donation',
#  881: 'money transfer',
#  975: 'money laundering',
#  1552: 'subway',
#  1553: 'pottery',
#  986: 'tv addicted person',
#  3272: 'secret intelligence service',
#  2591: 'tarot cards',
#  3266: 'jamaica',
#  2149: 'drug trafficking',
#  3392: 'voodoo',
#  3393: 'tombstone',
#  2671: 'heroin',
#  1308: 'secret identity',
#  3185: 'crocodile',
#  837: 'show business',
#  1551: 'indigenous',
#  703: 'detective',
#  906: 'job-hopping',
#  1406: 'night watchman',
#  4826: 'repair',
#  1411: 'brothel',
#  1735: 'amateur detective',
#  708: 'runaway',
#  714: 'child labour',
#  6783: 'orphanage',
#  1228: '1970s',
#  4721: 'violin',
#  2176: 'music teacher',
#  2587: 'married couple',
#  7307: 'routine',
#  7100: "neglect of one's spouse",
#  2699: 'fetish',
#  1904: 'life planning',
#  1225: 'print shop',
#  1226: 'printer',
#  770: 'scotland yard',
#  772: 'handcuffs',
#  1491: 'entertainer',
#  2310: 'procession',
#  2311: 'cabaret',
#  2051: 'intelligence',
#  4740: 'public',
#  1812: 'fbi',
#  5321: 'studio',
#  835: 'jewry',
#  1222: 'zurich',
#  1223: 'switzerland',
#  883: 'capri',
#  884: 'cinecittà studios',
#  888: 'screenwriter',
#  992: 'bus',
#  3725: 'pregnancy',
#  994: 'paralympics',
#  849: 'dc comics',
#  852: 'chemical',
#  853: 'crime fighter',
#  915: 'car thief',
#  916: 'marseille, france',
#  917: 'journalism',
#  919: 'smoking',
#  3929: 'hope',
#  1621: 'robber',
#  6062: 'hostility',
#  1307: 'butler',
#  1310: 'mentor',
#  1293: 'asia',
#  1253: 'roommate',
#  1669: 'wave',
#  1879: 'shower',
#  2340: 'paranoia',
#  2885: 'prison cell',
#  5337: 'culprit',
#  1360: 'minnesota',
#  1594: 'ex-boyfriend',
#  1595: 'ex-girlfriend',
#  1775: 'demonstration',
#  2020: 'revolution',
#  2052: 'traitor',
#  2200: 'generations conflict',
#  2338: 'alpine hut',
#  2339: 'political activism',
#  4194: 'catacombs',
#  4197: 'bite',
#  4198: 'descendant',
#  2398: 'narration',
#  4779: 'delinquent',
#  1370: 'shapeshifting',
#  1376: 'assault rifle',
#  11795: 'lasersight',
#  3088: 'bodyguard',
#  4562: 'rapper',
#  4565: 'dystopia',
#  4566: 'minidisc',
#  1438: 'office',
#  1439: 'flat',
#  1440: 'spaghetti',
#  1441: 'christmas party',
#  1487: 'tennis racket',
#  4224: 'singapore',
#  5941: 'calypso',
#  2580: 'shipwreck',
#  6211: 'fighter',
#  1477: 'world cup',
#  1627: 'patriotism',
#  5621: 'american football coach',
#  1480: 'baseball',
#  1482: 'trainer',
#  1484: 'pitcher',
#  1486: 'flirt',
#  1686: 'home run',
#  1501: 'allegory',
#  1502: 'marshal',
#  1505: 'famous score',
#  ...}

# %% [markdown]
# ### Request keywords movie function
# The function return a list of keywords for one movie.

# %%
import requests

def movie_keywords(movie_id: int):
    # Api data and movie index example
    api_key = "44f9a7f09387a49408460a6d158e1f44"

    # url using movie id = 2 example
    url = "https://api.themoviedb.org/3/movie/" + \
        str(movie_id) + "/keywords?api_key=" + api_key

    # Request keywords info
    request = requests.get(url)
    
    if request.status_code == 200:
        request = json.loads(request.text)
        if request.get("keywords") != None:
            word_list = []
            for line in request.get("keywords"):
                word_list.append(line["name"])
            return word_list

# %% [markdown]
# ## Looking for top 100 keywords in all movies
# We extract keywords for aleatory movies, we will use 100000 movies size sample to obtain a top 100 of keywords and adding to "dataset_movies.csv".

# %% [markdown]
# ### Iterative configuration

# %%
# Iteration parameters
n = len(df_movies)  # All movies size

nbatch_it = 100   # Number of batches to process in iteration
batch_size = 100    # Number of movies per batch
nmovies = batch_size*nbatch_it  # Total movies in iteration
counter = 0         # Count iterations movies

# Stop conditions (stop when batch has been processed)
batch_stop = None      # None for no stop

# Print resume configuration
print("------------ Iteration conditions ------------")
print("Total number of batches:", nbatch_it)
print("Batch size is:", batch_size)
print("Iteration will process {} movies".format(nmovies))
if batch_stop != None:
    print("Stop condition: {} batch".format(batch_stop))
# Out:
# ------------ Iteration conditions ------------
# Total number of batches: 100
# Batch size is: 100
# Iteration will process 10000 movies

# %% [markdown]
# ### Iterative process

# %%
import numpy as np
from time import time
import glob

start_time = time()
# Iterate batches
for i in range(nbatch_it+1)[1:]:
    # Create aleatory indexes
    indexs = np.random.randint(2, n, batch_size)  # not 1 because delete csv file

    # Print iteration info
    print('Processing Batch {}/{}.'.format(i, nbatch_it))
    print('Processed movies {}/{}.'.format(counter, nmovies), end='')

    data_list = []
    # Iterate movies batch
    for movie_id in df_movies.index[indexs]:
        
        # Get keywords for movies
        keywords_per_list = movie_keywords(movie_id)
        if keywords_per_list != None:
            # Append keywords to data list
            data_list.extend(keywords_per_list)
            counter += 1
        
        # Print iteration counter and status time every 10 iterations
        if counter % 10 == 0:
            estimate_time = np.round(
                (time()-start_time)/(3600*counter)*(nmovies-counter), 4)
            print('\rProcessed movies {}/{}. Remaining time: {:5.4f} h'.format(counter,
                  nmovies, estimate_time), end='')

    # Remove None values in list
    before = len(data_list)
    data_list = list(filter(None, data_list))
    print("\nNumber of error lines:", before - len(data_list))
    print("------------------------------------------------------")

    if glob.glob("export_files\keywords_list.csv"):
        # Append dataframe to csv file without header
        data = pd.DataFrame(data_list)
        data.to_csv("export_files\keywords_list.csv", mode="a", header=False)
    else:
        # Append dataframe to csv file with header
        data = pd.DataFrame(data_list,columns=["keywords"])
        data.to_csv("export_files\keywords_list.csv")

    # del data and clean memory
    del data
    del data_list
    gc.collect()

    # Stop condition
    if i == batch_stop:
        print("Iteration stop condition")
        print("batch {}/{} has been processed".format(i, nbatch_it))
        print("movie {}/{} has been processed".format(counter, nmovies))
        print("Elapsed time: {} h.".format((time()-start_time)/3600))
        break

if batch_stop == None:
    print("Iteration process complete")
    print("batch {}/{} has been processed".format(i, nbatch_it))
    print("movie {} has been processed".format(counter))
    print("Elapsed time: {} h.".format((time()-start_time)/3600))
# Out:
# Processing Batch 1/100.
# Processed movies 100/10000. Remaining time: 0.3781 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 2/100.
# Processed movies 200/10000. Remaining time: 0.3817 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 3/100.
# Processed movies 300/10000. Remaining time: 0.3749 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 4/100.
# Processed movies 400/10000. Remaining time: 0.3731 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 5/100.
# Processed movies 500/10000. Remaining time: 0.3642 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 6/100.
# Processed movies 600/10000. Remaining time: 0.3606 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 7/100.
# Processed movies 700/10000. Remaining time: 0.3573 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 8/100.
# Processed movies 800/10000. Remaining time: 0.3523 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 9/100.
# Processed movies 900/10000. Remaining time: 0.3468 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 10/100.
# Processed movies 1000/10000. Remaining time: 0.3421 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 11/100.
# Processed movies 1100/10000. Remaining time: 0.3379 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 12/100.
# Processed movies 1200/10000. Remaining time: 0.3337 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 13/100.
# Processed movies 1300/10000. Remaining time: 0.3303 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 14/100.
# Processed movies 1400/10000. Remaining time: 0.3261 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 15/100.
# Processed movies 1500/10000. Remaining time: 0.3221 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 16/100.
# Processed movies 1600/10000. Remaining time: 0.3180 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 17/100.
# Processed movies 1700/10000. Remaining time: 0.3139 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 18/100.
# Processed movies 1800/10000. Remaining time: 0.3110 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 19/100.
# Processed movies 1900/10000. Remaining time: 0.3072 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 20/100.
# Processed movies 2000/10000. Remaining time: 0.3034 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 21/100.
# Processed movies 2100/10000. Remaining time: 0.2992 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 22/100.
# Processed movies 2200/10000. Remaining time: 0.2954 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 23/100.
# Processed movies 2300/10000. Remaining time: 0.2914 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 24/100.
# Processed movies 2400/10000. Remaining time: 0.2876 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 25/100.
# Processed movies 2500/10000. Remaining time: 0.2837 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 26/100.
# Processed movies 2600/10000. Remaining time: 0.2797 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 27/100.
# Processed movies 2700/10000. Remaining time: 0.2756 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 28/100.
# Processed movies 2800/10000. Remaining time: 0.2719 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 29/100.
# Processed movies 2900/10000. Remaining time: 0.2679 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 30/100.
# Processed movies 3000/10000. Remaining time: 0.2639 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 31/100.
# Processed movies 3100/10000. Remaining time: 0.2598 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 32/100.
# Processed movies 3200/10000. Remaining time: 0.2557 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 33/100.
# Processed movies 3300/10000. Remaining time: 0.2519 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 34/100.
# Processed movies 3390/10000. Remaining time: 0.2490 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 35/100.
# Processed movies 3490/10000. Remaining time: 0.2452 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 36/100.
# Processed movies 3590/10000. Remaining time: 0.2412 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 37/100.
# Processed movies 3690/10000. Remaining time: 0.2372 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 38/100.
# Processed movies 3790/10000. Remaining time: 0.2335 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 39/100.
# Processed movies 3890/10000. Remaining time: 0.2297 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 40/100.
# Processed movies 3990/10000. Remaining time: 0.2260 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 41/100.
# Processed movies 4090/10000. Remaining time: 0.2221 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 42/100.
# Processed movies 4190/10000. Remaining time: 0.2185 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 43/100.
# Processed movies 4290/10000. Remaining time: 0.2147 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 44/100.
# Processed movies 4390/10000. Remaining time: 0.2109 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 45/100.
# Processed movies 4490/10000. Remaining time: 0.2070 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 46/100.
# Processed movies 4590/10000. Remaining time: 0.2030 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 47/100.
# Processed movies 4690/10000. Remaining time: 0.1994 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 48/100.
# Processed movies 4790/10000. Remaining time: 0.1955 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 49/100.
# Processed movies 4890/10000. Remaining time: 0.1920 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 50/100.
# Processed movies 4990/10000. Remaining time: 0.1881 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 51/100.
# Processed movies 5090/10000. Remaining time: 0.1844 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 52/100.
# Processed movies 5190/10000. Remaining time: 0.1808 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 53/100.
# Processed movies 5290/10000. Remaining time: 0.1769 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 54/100.
# Processed movies 5390/10000. Remaining time: 0.1731 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 55/100.
# Processed movies 5490/10000. Remaining time: 0.1692 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 56/100.
# Processed movies 5590/10000. Remaining time: 0.1656 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 57/100.
# Processed movies 5690/10000. Remaining time: 0.1617 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 58/100.
# Processed movies 5790/10000. Remaining time: 0.1580 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 59/100.
# Processed movies 5890/10000. Remaining time: 0.1544 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 60/100.
# Processed movies 5990/10000. Remaining time: 0.1506 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 61/100.
# Processed movies 6090/10000. Remaining time: 0.1469 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 62/100.
# Processed movies 6190/10000. Remaining time: 0.1430 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 63/100.
# Processed movies 6290/10000. Remaining time: 0.1393 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 64/100.
# Processed movies 6390/10000. Remaining time: 0.1355 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 65/100.
# Processed movies 6490/10000. Remaining time: 0.1318 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 66/100.
# Processed movies 6590/10000. Remaining time: 0.1280 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 67/100.
# Processed movies 6690/10000. Remaining time: 0.1242 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 68/100.
# Processed movies 6790/10000. Remaining time: 0.1205 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 69/100.
# Processed movies 6890/10000. Remaining time: 0.1167 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 70/100.
# Processed movies 6990/10000. Remaining time: 0.1130 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 71/100.
# Processed movies 7090/10000. Remaining time: 0.1093 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 72/100.
# Processed movies 7190/10000. Remaining time: 0.1055 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 73/100.
# Processed movies 7290/10000. Remaining time: 0.1017 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 74/100.
# Processed movies 7390/10000. Remaining time: 0.0979 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 75/100.
# Processed movies 7490/10000. Remaining time: 0.0942 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 76/100.
# Processed movies 7590/10000. Remaining time: 0.0904 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 77/100.
# Processed movies 7690/10000. Remaining time: 0.0867 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 78/100.
# Processed movies 7790/10000. Remaining time: 0.0829 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 79/100.
# Processed movies 7890/10000. Remaining time: 0.0792 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 80/100.
# Processed movies 7990/10000. Remaining time: 0.0756 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 81/100.
# Processed movies 8090/10000. Remaining time: 0.0718 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 82/100.
# Processed movies 8190/10000. Remaining time: 0.0681 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 83/100.
# Processed movies 8290/10000. Remaining time: 0.0643 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 84/100.
# Processed movies 8390/10000. Remaining time: 0.0605 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 85/100.
# Processed movies 8490/10000. Remaining time: 0.0568 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 86/100.
# Processed movies 8590/10000. Remaining time: 0.0531 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 87/100.
# Processed movies 8690/10000. Remaining time: 0.0493 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 88/100.
# Processed movies 8790/10000. Remaining time: 0.0455 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 89/100.
# Processed movies 8890/10000. Remaining time: 0.0418 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 90/100.
# Processed movies 8990/10000. Remaining time: 0.0380 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 91/100.
# Processed movies 9090/10000. Remaining time: 0.0343 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 92/100.
# Processed movies 9190/10000. Remaining time: 0.0305 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 93/100.
# Processed movies 9290/10000. Remaining time: 0.0267 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 94/100.
# Processed movies 9390/10000. Remaining time: 0.0230 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 95/100.
# Processed movies 9490/10000. Remaining time: 0.0192 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 96/100.
# Processed movies 9590/10000. Remaining time: 0.0154 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 97/100.
# Processed movies 9690/10000. Remaining time: 0.0117 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 98/100.
# Processed movies 9790/10000. Remaining time: 0.0079 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 99/100.
# Processed movies 9890/10000. Remaining time: 0.0041 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 100/100.
# Processed movies 9990/10000. Remaining time: 0.0004 h
# Number of error lines: 0
# ------------------------------------------------------
# Iteration process complete
# batch 100/100 has been processed
# movie 9993 has been processed
# Elapsed time: 0.3763576432069143 h.

# %% [markdown]
# ### Top 100 keywords

# %%
keywords = pd.read_csv("export_files\keywords_list.csv")
keywords.drop("Unnamed: 0",axis=1,inplace=True)
top_100_keywords = keywords.value_counts().sort_values(ascending=False)[:100]
top_100_keywords
# Out:
# keywords
# short film                563
# woman director            418
# based on novel or book    154
# murder                    151
# concert                   100
#                          ...
# world war i                20
# gay interest               20
# 1980s                      19
# school                     19
# gangster                   19
# Length: 100, dtype: int64

# %%
temp = []
for keyword in top_100_keywords.index:
    temp.append(keyword[0])
top_100_keywords = temp
del temp
top_100_keywords
# Out:
# ['short film',
#  'woman director',
#  'based on novel or book',
#  'murder',
#  'concert',
#  'silent film',
#  'biography',
#  'musical',
#  'sports',
#  'christmas',
#  'lgbt',
#  'world war ii',
#  'stand-up comedy',
#  'revenge',
#  'softcore',
#  'anime',
#  'martial arts',
#  'philippines',
#  'friendship',
#  'based on true story',
#  'family',
#  'love',
#  'black and white',
#  'sequel',
#  'coming of age',
#  'politics',
#  'wrestling',
#  'romance',
#  'drugs',
#  'horror',
#  'parent child relationship',
#  'serial killer',
#  'ghost',
#  'kidnapping',
#  'supernatural',
#  'monster',
#  'pre-code',
#  'vampire',
#  'high school',
#  'slasher',
#  'new york city',
#  'based on play or musical',
#  'police',
#  'satire',
#  'gay',
#  'gore',
#  'found footage',
#  'holiday',
#  'religion',
#  'stop motion',
#  'opera',
#  "rock 'n' roll",
#  'erotic movie',
#  'rape',
#  'prison',
#  'nature',
#  'dark comedy',
#  'art',
#  'football (soccer)',
#  'japan',
#  'remake',
#  'zombie',
#  'dance',
#  'superhero',
#  'infidelity',
#  'dog',
#  'africa',
#  'nazi',
#  'mexico',
#  'mockumentary',
#  'racism',
#  'surrealism',
#  'live performance',
#  'parody',
#  'marriage',
#  'london, england',
#  'thriller',
#  'doctor',
#  'avant-garde',
#  'educational',
#  'relationship',
#  'fairy tale',
#  '19th century',
#  'small town',
#  'los angeles, california',
#  'sibling relationship',
#  'cartoon',
#  'neo-noir',
#  'island',
#  'husband wife relationship',
#  'magic',
#  'suicide',
#  'spy',
#  'family relationships',
#  'road trip',
#  'world war i',
#  'gay interest',
#  '1980s',
#  'school',
#  'gangster']

# %% [markdown]
# ### Binarize keywords features

# %%
def binary_keyword(movie_id: int):
    row = movie_keywords(movie_id)
    if row != None:
        keywords_by_movie_dict = {}
        keywords_by_movie_dict["id"] = movie_id
            
        for all_key in top_100_keywords:
            keywords_by_movie_dict[all_key] = 0
            for keyword in row:
                if keyword == all_key:
                    keywords_by_movie_dict[all_key] = 1
        return keywords_by_movie_dict

# %%
binary_keyword(2)
# Out:
# {'id': 2,
#  'short film': 0,
#  'woman director': 0,
#  'based on novel or book': 0,
#  'silent film': 0,
#  'murder': 0,
#  'sports': 0,
#  'revenge': 0,
#  'biography': 0,
#  'lgbt': 0,
#  'anime': 0,
#  'musical': 0,
#  'coming of age': 0,
#  'love': 0,
#  'martial arts': 0,
#  'stand-up comedy': 0,
#  'parody': 0,
#  'world war ii': 0,
#  'black and white': 0,
#  'concert': 0,
#  'softcore': 0,
#  'parent child relationship': 0,
#  'christmas': 0,
#  'wrestling': 0,
#  'friendship': 0,
#  'live performance': 0,
#  'drugs': 0,
#  'found footage': 0,
#  'new york city': 0,
#  'philippines': 0,
#  'family': 0,
#  'rape': 0,
#  'stop motion': 0,
#  'vampire': 0,
#  'prison': 1,
#  'based on true story': 0,
#  'sequel': 0,
#  'police': 0,
#  'kidnapping': 0,
#  'gay': 0,
#  'spy': 0,
#  'remake': 0,
#  'supernatural': 0,
#  'small town': 0,
#  'gay interest': 0,
#  'based on play or musical': 0,
#  '19th century': 0,
#  'sibling relationship': 0,
#  'high school': 0,
#  'romance': 0,
#  'football (soccer)': 0,
#  'spoof': 0,
#  'infidelity': 0,
#  'surrealism': 0,
#  'road trip': 0,
#  'space': 0,
#  'orphan': 0,
#  'japan': 0,
#  'torture': 0,
#  'monster': 0,
#  'erotic movie': 0,
#  'b movie': 0,
#  '1980s': 0,
#  'lost film': 0,
#  'africa': 0,
#  'husband wife relationship': 0,
#  'lawyer': 0,
#  'slasher': 0,
#  'horror': 0,
#  'secret': 0,
#  'aids': 0,
#  'zombie': 0,
#  'racism': 0,
#  'ghost': 0,
#  'opera': 0,
#  'thriller': 0,
#  'cartoon': 0,
#  'creature': 0,
#  'cannibal': 0,
#  'dance': 0,
#  'scientist': 0,
#  'dark comedy': 0,
#  'island': 0,
#  'christian film': 0,
#  'death': 0,
#  'dog': 0,
#  'politics': 0,
#  'prostitute': 0,
#  'holiday': 0,
#  'based on comic': 0,
#  'marriage': 0,
#  'based on manga': 0,
#  'poverty': 0,
#  'true crime': 0,
#  'money': 0,
#  'robot': 0,
#  'serial killer': 0,
#  'family relationships': 0,
#  'rural area': 0,
#  'superhero': 0,
#  'demon': 0}

# %% [markdown]
# ## Iterative keyword features extraction

# %% [markdown]
# ### Iterative configuration

# %%
# Iteration parameters
n = len(df_movies)  # All movies size
nbatch = 4000       # Number of Batches

# Create index partition
indexs = np.linspace(0, len(df_movies), nbatch, dtype=int)
batch_size = indexs[1]

# Initial batch, stop batch and initial counter (movies)
a = 1                 # Initiates on batch a -> [1,nbatch]
b = 100                 # End on batch b -> [1,nbatch]
nbatch_it = b-a+1   # Number of batches to process in iteration
nmovies = batch_size*nbatch_it  # Total movies in iteration
counter = 0         # Count iterations movies

# Stop conditions (stop when batch has been processed)
batch_stop = None      # None for no stop

# Print resume configuration
print("------------ Iteration conditions ------------")
print("Total number of batches:", nbatch)
print("Batch size is:", batch_size)
print("Iteration will process from {} to {} batch".format(a, b))
print("Iteration will process {} movies".format(nmovies))
if batch_stop != None:
    print("Stop condition: {} batch".format(batch_stop))
# Out:
# ------------ Iteration conditions ------------
# Total number of batches: 4000
# Batch size is: 172
# Iteration will process from 1 to 100 batch
# Iteration will process 17200 movies

# %% [markdown]
# ### Iterative process

# %%
start_time = time()
# Iterate batches
for i in range(len(indexs)+1)[a:(b+1)]:
    # Print iteration info
    print('Processing Batch {}/{}.'.format(i, b))
    print('Processed movies {}/{}.'.format(counter, nmovies), end='')

    data_list = []
    # Iterate movies batch
    for movie_id in df_movies.index[indexs[i-1]:indexs[i]]:
        # Append row to data list
        data_list.append(binary_keyword(movie_id))
        counter += 1
        # Print iteration counter and status time every 10 iterations
        if counter % 10 == 0:
            estimate_time = np.round(
                (time()-start_time)/(3600*counter)*(nmovies-counter), 4)
            print('\rProcessed movies {}/{}. Remaining time: {:5.4f} h'.format(counter,
                  nmovies, estimate_time), end='')

    # Remove None values in list
    before = len(data_list)
    data_list = list(filter(None, data_list))
    print("\nNumber of error lines:", before - len(data_list))
    print("------------------------------------------------------")

    if i == 1:
        # Append dataframe to csv file with header
        data = pd.DataFrame(data_list)
        data.set_index("id", inplace=True)
        data.to_csv("export_files\dataset_keywords.csv")
    else:
        # Append dataframe to csv file without header
        data = pd.DataFrame(data_list)
        data.set_index("id", inplace=True)
        data.to_csv("export_files\dataset_keywords.csv", mode="a", header=False)

    # del data and clean memory
    del data
    del data_list
    gc.collect()

    # Stop condition
    if i == batch_stop:
        print("Iteration stop condition")
        print("batch {}/{} has been processed".format(i, b))
        print("movie {}/{} has been processed".format(counter, nmovies))
        print("Elapsed time: {} h.".format((time()-start_time)/3600))
        break

if batch_stop == None:
    print("Iteration process complete")
    print("batch {}/{} has been processed".format(i, b))
    print("movie {} has been processed".format(counter))
    print("Elapsed time: {} h.".format((time()-start_time)/3600))
# Out:
# Processing Batch 1/100.
# Processed movies 170/17200. Remaining time: 0.6259 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 2/100.
# Processed movies 340/17200. Remaining time: 0.6111 h
# Number of error lines: 0
# ------------------------------------------------------
# Processing Batch 3/100.
# Processed movies 360/17200. Remaining time: 0.6106 h
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13388\3534928230.py in <module>
#      10     for movie_id in df_movies.index[indexs[i-1]:indexs[i]]:
#      11         # Append row to data list
# ---> 12         data_list.append(binary_keyword(movie_id))
#      13         counter += 1
#      14         # Print iteration counter and status time every 10 iterations
#
# ~\AppData\Local\Temp\ipykernel_13388\3023995263.py in binary_keyword(movie_id)
#       1 def binary_keyword(movie_id: int):
# ----> 2     row = movie_keywords(movie_id)
#       3     if row != None:
#       4         keywords_by_movie_dict = {}
#       5         keywords_by_movie_dict["id"] = movie_id
#
# ~\AppData\Local\Temp\ipykernel_13388\6631032.py in movie_keywords(movie_id)
#      10
#      11     # Request keywords info
# ---> 12     request = requests.get(url)
#      13
#      14     if request.status_code == 200:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\AppData\Local\Programs\Python\Python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Join Dataframe

# %% [markdown]
# ## Extracting collections features

# %%
collections = pd.read_json(
    "export_files\collection_ids_03_24_2022.json", lines=True)
collections.set_index("id", inplace=True)
collections

# %% [markdown]
# ## Extract regions features

# %%
import requests
import json
import pandas as pd

# Api data and movie index example
api_key = "44f9a7f09387a49408460a6d158e1f44"

# URL to retrieve movie info
url = "https://api.themoviedb.org/3/watch/providers/regions?api_key=" + \
    str(api_key)+"&language=en-US"

# Making a request example
row = json.loads(requests.get(url).text).get("results")

# Create pandas dataframe
regions = pd.DataFrame(row)
regions.set_index("iso_3166_1", inplace=True)
regions.drop("native_name", axis=1, inplace=True)
regions.to_json("json_dict\regions.json")
regions
